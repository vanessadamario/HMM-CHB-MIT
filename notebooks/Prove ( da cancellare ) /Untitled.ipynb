# %%
import pickle
from regain.hmm.utils_pred import thetas_comparison

# %%
with open('Prec.pickle', 'rb') as f:
    [returns, prec_real] = pickle.load(f)

# %%
returns
# Out:
# {'0': array([[ 1.08712711e+00, -1.06054661e-15, -6.49197819e-03,
#           1.31871186e-02,  9.50048394e-01,  8.09735273e-03,
#          -9.15154507e-16,  1.07739106e-02,  1.86034435e-03,
#           1.20042865e-15],
#         [ 8.42781222e-16,  9.48763498e-01,  1.47984944e-15,
#           3.93559606e-15,  6.57665028e-16, -2.08725838e-02,
#           8.37928437e-01, -3.59788283e-16,  1.48793871e-02,
#           6.61377910e-02],
#         [-6.49197819e-03,  9.54551098e-16,  9.67563957e-01,
#           5.60842435e-03,  2.61200366e-03, -1.47001054e-02,
#          -1.77827565e-02, -4.17951294e-02, -9.43689571e-16,
#           8.61874105e-01],
#         [ 1.31871186e-02,  2.72440246e-15,  5.60842435e-03,
#           9.93574639e-01, -8.40906817e-03,  9.02644041e-01,
#           2.93715816e-15,  9.87824473e-17, -1.52655666e-16,
#           3.69074577e-02],
#         [ 9.50048394e-01, -7.80632062e-16,  2.61200366e-03,
#          -8.40906817e-03,  1.02861433e+00, -1.09651341e-15,
# ...

# %%
mcc, f1 = thetas_comparison(prec_real,returns)
# Out:
# 0.28867513459481287
# 0.27548658250966984
# 0.28867513459481287
# 0.28867513459481287
# 0.28867513459481287
# 0.2626128657194451
# 0.30223526241349447
# 0.27548658250966984
# 0.27548658250966984
# 0.28867513459481287

# %%
print(mcc)
# Out:
# 0.28346835486360134

# %%
print(f1)
# Out:
# 0.19999999999999998

# %%
with open('Res_prec.pickle', 'wb') as f:
    pickle.dump([mcc, f1], f)
